# %% [markdown]
# # Data Preprocessing and Cleaning

# %% [markdown]
# # Libraries :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import io

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Getting Data :

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
resp = requests.get(url)
text = io.StringIO(resp.text)
df = pd.read_csv(text)

# %% [markdown]
# # Understanding Data :

# %%
df.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df.tail(5)
# Out:
#      3   ? alfa-romero     gas    std   two convertible  rwd  front  88.60  \
# 199 -1  95       volvo     gas    std  four       sedan  rwd  front  109.1
# 200 -1  95       volvo     gas  turbo  four       sedan  rwd  front  109.1
# 201 -1  95       volvo     gas    std  four       sedan  rwd  front  109.1
# 202 -1  95       volvo  diesel  turbo  four       sedan  rwd  front  109.1
# 203 -1  95       volvo     gas  turbo  four       sedan  rwd  front  109.1
#
#      ...  130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 199  ...  141  mpfi  3.78  3.15   9.5  114  5400  23  28  16845
# 200  ...  141  mpfi  3.78  3.15   8.7  160  5300  19  25  19045
# 201  ...  173  mpfi  3.58  2.87   8.8  134  5500  18  23  21485
# 202  ...  145   idi  3.01  3.40  23.0  106  4800  26  27  22470
# 203  ...  141  mpfi  3.78  3.15   9.5  114  5400  19  25  22625
#
# [5 rows x 26 columns]

# %% [markdown]
# # Replacing Headers :

# %%
headers=['symboling','normalized-losses','make','fuel-type','aspiration',
         'num-of-doors','body-style','drive-wheels','engine-location','wheel-base',
         'length','width','height','curb-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']

df.columns = headers

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
#
# [5 rows x 26 columns]

# %% [markdown]
# # Replacing "?" with NaN :

# %%
df1 = df.replace('?',np.NaN)
df1.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
#
# [5 rows x 26 columns]

# %%
df = df1.dropna(subset=["price"],axis=0)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
#
# [5 rows x 26 columns]

# %%
# Find the name of the columns in dataframe

print(df.columns)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Understanding the Datatypes :

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# # Statistical summary of the Data :

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.830000   98.848000  174.228000   65.898000   53.791500
# std      1.248557    6.038261   12.347132    2.102904    2.428449
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.675000   64.175000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.675000   55.525000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   200.000000   200.000000         200.000000  200.000000   200.000000
# mean   2555.705000   126.860000          10.170100   25.200000    30.705000
# std     518.594552    41.650501           4.014163    6.432487     6.827227
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2163.000000    97.750000           8.575000   19.000000    25.000000
# 50%    2414.000000   119.500000           9.000000   24.000000    30.000000
# 75%    2928.250000   142.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %%
df[['symboling','wheel-base']].describe()
# Out:
#         symboling  wheel-base
# count  200.000000  200.000000
# mean     0.830000   98.848000
# std      1.248557    6.038261
# min     -2.000000   86.600000
# 25%      0.000000   94.500000
# 50%      1.000000   97.000000
# 75%      2.000000  102.400000
# max      3.000000  120.900000

# %% [markdown]
# # Missingness Evaluation :

# %%
# 1. .isnull()
# 2. .notnull()

missing_data = df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
#    fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        False  False   False              False       False     False
# 1        False  False   False              False       False     False
# 2        False  False   False              False       False     False
# 3        False  False   False              False       False     False
# 4        False  False   False              False       False     False
#
#    city-mpg  highway-mpg  price
# 0     False        False  False
# 1     False        False  False
# 2     False        False  False
# 3     False        False  False
# 4     False        False  False
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    36
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %% [markdown]
# # Dealing with missing values :

# %%
# 1. drop ( row,column)
# 2. replace ( mean,median,other functions)

# %% [markdown]
# ### 1. Column -> normalized-losses

# %%
# calculate mean for normalized-losses

avg_norm_loss = df['normalized-losses'].astype('float').mean()
print("Average normalized losses is: ",avg_norm_loss)

# now replace NaN with mean

df['normalized-losses'].replace(np.nan,avg_norm_loss,inplace=True)
print("Values of normliazed losses is replaced with mean: ")
df.head(5)
# Out:
# Average normalized losses is:  122.0
# Values of normliazed losses is replaced with mean:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          1               122  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               122         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### 2. Column -> bore

# %%
# now replace mean for the column bore

avg_bore = df['bore'].astype('float').mean()
print("Avg bore :",avg_bore)

# replace

df['bore'].replace(np.NaN,avg_bore,inplace=True)
print("After replacing: ")
df
# Out:
# Avg bore : 3.3300000000000005
# After replacing:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            152         mpfi  2.68    3.47               9.0        154
# 2            109         mpfi  3.19    3.40              10.0        102
# 3            136         mpfi  3.19    3.40               8.0        115
# 4            136         mpfi  3.19    3.40               8.5        110
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5        114
# 200          141         mpfi  3.78    3.15               8.7        160
# 201          173         mpfi  3.58    2.87               8.8        134
# 202          145          idi  3.01    3.40              23.0        106
# 203          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  16500
# 1        5000       19          26  16500
# 2        5500       24          30  13950
# 3        5500       18          22  17450
# 4        5500       19          25  15250
# ..        ...      ...         ...    ...
# 199      5400       23          28  16845
# 200      5300       19          25  19045
# 201      5500       18          23  21485
# 202      4800       26          27  22470
# 203      5400       19          25  22625
#
# [200 rows x 26 columns]

# %%
# now check:

df['bore'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### 3. Column -> stroke

# %%
# column stroke

# mean
avg_stroke = df['stroke'].astype('float').mean()
print("Avg stroke is: ",avg_stroke)

# replace 
df['stroke'].replace(np.NaN,avg_stroke,inplace=True)
print("After replacing: ")
df
# Out:
# Avg stroke is:  3.2598469387755036
# After replacing:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            152         mpfi  2.68    3.47               9.0        154
# 2            109         mpfi  3.19    3.40              10.0        102
# 3            136         mpfi  3.19    3.40               8.0        115
# 4            136         mpfi  3.19    3.40               8.5        110
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5        114
# 200          141         mpfi  3.78    3.15               8.7        160
# 201          173         mpfi  3.58    2.87               8.8        134
# 202          145          idi  3.01    3.40              23.0        106
# 203          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  16500
# 1        5000       19          26  16500
# 2        5500       24          30  13950
# 3        5500       18          22  17450
# 4        5500       19          25  15250
# ..        ...      ...         ...    ...
# 199      5400       23          28  16845
# 200      5300       19          25  19045
# 201      5500       18          23  21485
# 202      4800       26          27  22470
# 203      5400       19          25  22625
#
# [200 rows x 26 columns]

# %% [markdown]
# ### 4. Column -> horse power

# %%
# horse power column

avg_horse = df['horsepower'].astype('float').mean()
print(avg_horse)

# replace

df['horsepower'].replace(np.NaN,avg_horse,inplace=True)
df
# Out:
# 103.35858585858585
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            152         mpfi  2.68    3.47               9.0        154
# 2            109         mpfi  3.19    3.40              10.0        102
# 3            136         mpfi  3.19    3.40               8.0        115
# 4            136         mpfi  3.19    3.40               8.5        110
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5        114
# 200          141         mpfi  3.78    3.15               8.7        160
# 201          173         mpfi  3.58    2.87               8.8        134
# 202          145          idi  3.01    3.40              23.0        106
# 203          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  16500
# 1        5000       19          26  16500
# 2        5500       24          30  13950
# 3        5500       18          22  17450
# 4        5500       19          25  15250
# ..        ...      ...         ...    ...
# 199      5400       23          28  16845
# 200      5300       19          25  19045
# 201      5500       18          23  21485
# 202      4800       26          27  22470
# 203      5400       19          25  22625
#
# [200 rows x 26 columns]

# %% [markdown]
# ### 5. Column -> peak-rpm

# %%
# column peak-rpm

# mean

avg_rpm = df['peak-rpm'].astype('float').mean()
print(avg_rpm)

# replace

df['peak-rpm'].replace(np.NaN,avg_rpm,inplace=True)
df
# Out:
# 5118.181818181818
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            152         mpfi  2.68    3.47               9.0        154
# 2            109         mpfi  3.19    3.40              10.0        102
# 3            136         mpfi  3.19    3.40               8.0        115
# 4            136         mpfi  3.19    3.40               8.5        110
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5        114
# 200          141         mpfi  3.78    3.15               8.7        160
# 201          173         mpfi  3.58    2.87               8.8        134
# 202          145          idi  3.01    3.40              23.0        106
# 203          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  16500
# 1        5000       19          26  16500
# 2        5500       24          30  13950
# 3        5500       18          22  17450
# 4        5500       19          25  15250
# ..        ...      ...         ...    ...
# 199      5400       23          28  16845
# 200      5300       19          25  19045
# 201      5500       18          23  21485
# 202      4800       26          27  22470
# 203      5400       19          25  22625
#
# [200 rows x 26 columns]

# %% [markdown]
# ### 6. Column -> num-of-doors

# %%
# We can clearly see that for the column ( num-of-doors ) . 
# four is the most frequent item. therefore we are replacing with "Four"

df['num-of-doors'].value_counts()
# Out:
# four    113
# two      85
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].replace(np.NaN,'four',inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# Now we can see all the missing values are handled appropriatley.

# %% [markdown]
# # Checking for the format of the data :

# %%
# The Last Step in Data Cleaning is to check the format of tha datas.

df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df['drive-wheels']=df['drive-wheels'].replace('4wd','fwd')

# %% [markdown]
# # Data Normalization :

# %%
# Normalization is used to transform the values into similar range

# %%
df['length'] = (df['length'] - df['length'].min())/(df['length'].max()-df['length'].min())
df['width'] = (df['width'] - df['width'].min())/(df['width'].max()-df['width'].min())
df['height'] = (df['height'] - df['height'].min())/(df['height'].max()-df['height'].min())

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          fwd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          152         mpfi  2.68    3.47               9.0        154
# 2          109         mpfi  3.19    3.40              10.0        102
# 3          136         mpfi  3.19    3.40               8.0        115
# 4          136         mpfi  3.19    3.40               8.5        110
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  16500.0
# 1    5000.0       19           26  16500.0
# 2    5500.0       24           30  13950.0
# 3    5500.0       18           22  17450.0
# 4    5500.0       19           25  15250.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Data Standardization :

# %%
# Transformaing the data into a common format

# where  "city-mpg" and "highway-mpg" are in unit mpg. where some country accept it as L/100km.

# so transform it

df['city-L/100km'] = 235/df['city-mpg']
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          fwd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111   5000.0        21
# 1         mpfi  2.68    3.47                9.0        154   5000.0        19
# 2         mpfi  3.19    3.40               10.0        102   5500.0        24
# 3         mpfi  3.19    3.40                8.0        115   5500.0        18
# 4         mpfi  3.19    3.40                8.5        110   5500.0        19
#
#   highway-mpg    price  city-L/100km
# 0          27  16500.0     11.190476
# 1          26  16500.0     12.368421
# 2          30  13950.0      9.791667
# 3          22  17450.0     13.055556
# 4          25  15250.0     12.368421
#
# [5 rows x 27 columns]

# %% [markdown]
# # Indicator Variable :

# %% [markdown]
# ### 1. Column -> fuel-type

# %% [markdown]
# An indicator variable (or dummy variable) is a numerical variable used to label categories

# %%
# The column "fuel-type" has 2 unique values: "gas" or "diesel".
# using pandas get_dummies


dummy_variable_1 = pd.get_dummies(df['fuel-type'])
dummy_variable_1.head(5)
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
# Now change the column names for better understanding

dummy_variable_1.rename(columns={'gas':'fuel-type-gas','diesel':'fuel-type-diesel'},inplace=True)
dummy_variable_1.head(5)
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
# merge data from df and dummy_variable_1

df = pd.concat([df,dummy_variable_1],axis=1)
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          fwd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    stroke  compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  \
# 0    2.68                9.0         111    5000.0       21          27
# 1    3.47                9.0         154    5000.0       19          26
# 2    3.40               10.0         102    5500.0       24          30
# 3    3.40                8.0         115    5500.0       18          22
# 4    3.40                8.5         110    5500.0       19          25
#
#      price city-L/100km  fuel-type-diesel  fuel-type-gas
# 0  16500.0    11.190476                 0              1
# 1  16500.0    12.368421                 0              1
# 2  13950.0     9.791667                 0              1
# 3  17450.0    13.055556                 0              1
# 4  15250.0    12.368421                 0              1
#
# [5 rows x 29 columns]

# %%
# now drop fuel_type

df.drop("fuel-type",axis=1,inplace=True)
df.head(5)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          1                122  alfa-romero        std          two
# 2          2                164         audi        std         four
# 3          2                164         audi        std         four
# 4          2                122         audi        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.413433  ...
# 1    hatchback          rwd           front        94.5  0.449254  ...
# 2        sedan          fwd           front        99.8  0.529851  ...
# 3        sedan          fwd           front        99.4  0.529851  ...
# 4        sedan          fwd           front        99.8  0.540299  ...
#
#    stroke  compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  \
# 0    2.68                9.0         111   5000.0       21           27
# 1    3.47                9.0         154   5000.0       19           26
# 2    3.40               10.0         102   5500.0       24           30
# 3    3.40                8.0         115   5500.0       18           22
# 4    3.40                8.5         110   5500.0       19           25
#
#      price  city-L/100km  fuel-type-diesel  fuel-type-gas
# 0  16500.0     11.190476                 0              1
# 1  16500.0     12.368421                 0              1
# 2  13950.0      9.791667                 0              1
# 3  17450.0     13.055556                 0              1
# 4  15250.0     12.368421                 0              1
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 2. column -> aspiration

# %%
dummy_variable_2 = pd.get_dummies(df['aspiration'])
dummy_variable_2.head(5)
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variable_2.rename(columns={'std':'aspiration-std','turbo':'aspiration-turbo'},inplace=True)
dummy_variable_2.head(5)
# Out:
#    aspiration-std  aspiration-turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0

# %%
df = pd.concat([df,dummy_variable_2],axis=1)
df.drop('aspiration',axis=1,inplace=True)
df.head(5)
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          1                122  alfa-romero          two    hatchback
# 2          2                164         audi         four        sedan
# 3          2                164         audi         four        sedan
# 4          2                122         audi          two        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.413433  0.324786  ...
# 1          rwd           front        94.5  0.449254  0.444444  ...
# 2          fwd           front        99.8  0.529851  0.504274  ...
# 3          fwd           front        99.4  0.529851  0.521368  ...
# 4          fwd           front        99.8  0.540299  0.512821  ...
#
#    horsepower  peak-rpm city-mpg highway-mpg    price city-L/100km  \
# 0         111    5000.0       21          27  16500.0    11.190476
# 1         154    5000.0       19          26  16500.0    12.368421
# 2         102    5500.0       24          30  13950.0     9.791667
# 3         115    5500.0       18          22  17450.0    13.055556
# 4         110    5500.0       19          25  15250.0    12.368421
#
#    fuel-type-diesel  fuel-type-gas  aspiration-std aspiration-turbo
# 0                 0              1               1                0
# 1                 0              1               1                0
# 2                 0              1               1                0
# 3                 0              1               1                0
# 4                 0              1               1                0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Now the data is cleaned.

# %% [markdown]
# # FINAL DATA :

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          1                122  alfa-romero          two    hatchback
# 2          2                164         audi         four        sedan
# 3          2                164         audi         four        sedan
# 4          2                122         audi          two        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.413433  0.324786  ...
# 1          rwd           front        94.5  0.449254  0.444444  ...
# 2          fwd           front        99.8  0.529851  0.504274  ...
# 3          fwd           front        99.4  0.529851  0.521368  ...
# 4          fwd           front        99.8  0.540299  0.512821  ...
#
#    horsepower  peak-rpm city-mpg highway-mpg    price city-L/100km  \
# 0         111    5000.0       21          27  16500.0    11.190476
# 1         154    5000.0       19          26  16500.0    12.368421
# 2         102    5500.0       24          30  13950.0     9.791667
# 3         115    5500.0       18          22  17450.0    13.055556
# 4         110    5500.0       19          25  15250.0    12.368421
#
#    fuel-type-diesel  fuel-type-gas  aspiration-std aspiration-turbo
# 0                 0              1               1                0
# 1                 0              1               1                0
# 2                 0              1               1                0
# 3                 0              1               1                0
# 4                 0              1               1                0
#
# [5 rows x 29 columns]

# %% [markdown]
# # EDA -> Exploratory Data Analysis

# %% [markdown]
# ## Analyzing individual feature patterns using visulaization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
# for the plot should appear in same window

# %%
# check the data type of the column peak-rpm

df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.469772   -0.529145 -0.364511
# normalized-losses   0.469772           1.000000   -0.057068  0.019433
# wheel-base         -0.529145          -0.057068    1.000000  0.879005
# length             -0.364511           0.019433    0.879005  1.000000
# width              -0.237262           0.086961    0.814593  0.857271
# height             -0.542261          -0.377664    0.583789  0.492955
# curb-weight        -0.234743           0.099404    0.787584  0.881058
# engine-size        -0.112069           0.112362    0.576779  0.685531
# bore               -0.145667          -0.029867    0.501534  0.610817
# stroke              0.008244           0.055759    0.144675  0.120888
# compression-ratio  -0.181073          -0.114738    0.249689  0.159203
# peak-rpm            0.284011           0.239580   -0.364971 -0.286754
# city-mpg           -0.030158          -0.225255   -0.480029 -0.667658
# highway-mpg         0.041248          -0.182011   -0.552211 -0.700186
# price              -0.083327           0.133999    0.589147  0.691044
# city-L/100km        0.062423           0.238712    0.484047  0.659174
# fuel-type-diesel   -0.195381          -0.101574    0.306706  0.210616
# fuel-type-gas       0.195381           0.101574   -0.306706 -0.210616
# aspiration-std      0.050995           0.006915   -0.254907 -0.229294
# aspiration-turbo   -0.050995          -0.006915    0.254907  0.229294
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.237262 -0.542261    -0.234743    -0.112069 -0.145667
# normalized-losses  0.086961 -0.377664     0.099404     0.112362 -0.029867
# wheel-base         0.814593  0.583789     0.787584     0.576779  0.501534
# length             0.857271  0.492955     0.881058     0.685531  0.610817
# width              1.000000  0.300995     0.867720     0.731100  0.548478
# height             0.300995  1.000000     0.310660     0.076255  0.187794
# curb-weight        0.867720  0.310660     1.000000     0.849090  0.644532
# engine-size        0.731100  0.076255     0.849090     1.000000  0.572786
# bore               0.548478  0.187794     0.644532     0.572786  1.000000
# stroke             0.182855 -0.081273     0.168642     0.208004 -0.051087
# compression-ratio  0.189008  0.259526     0.156444     0.029005  0.002021
# peak-rpm          -0.247388 -0.315756    -0.279411    -0.256702 -0.267010
# city-mpg          -0.638155 -0.057087    -0.750390    -0.651002 -0.581365
# highway-mpg       -0.684700 -0.111568    -0.795515    -0.679877 -0.590753
# price              0.752795  0.137284     0.834420     0.872337  0.543431
# city-L/100km       0.677111  0.008923     0.785868     0.745337  0.554069
# fuel-type-diesel   0.243448  0.281198     0.221082     0.070925  0.055371
# fuel-type-gas     -0.243448 -0.281198    -0.221082    -0.070925 -0.055371
# aspiration-std    -0.304459 -0.086531    -0.322097    -0.110278 -0.229304
# aspiration-turbo   0.304459  0.086531     0.322097     0.110278  0.229304
#
#                      stroke  compression-ratio  peak-rpm  city-mpg  \
# symboling          0.008244          -0.181073  0.284011 -0.030158
# normalized-losses  0.055759          -0.114738  0.239580 -0.225255
# wheel-base         0.144675           0.249689 -0.364971 -0.480029
# length             0.120888           0.159203 -0.286754 -0.667658
# width              0.182855           0.189008 -0.247388 -0.638155
# height            -0.081273           0.259526 -0.315756 -0.057087
# curb-weight        0.168642           0.156444 -0.279411 -0.750390
# engine-size        0.208004           0.029005 -0.256702 -0.651002
# bore              -0.051087           0.002021 -0.267010 -0.581365
# stroke             1.000000           0.186761 -0.066173 -0.040677
# compression-ratio  0.186761           1.000000 -0.436244  0.330897
# peak-rpm          -0.066173          -0.436244  1.000000 -0.116308
# city-mpg          -0.040677           0.330897 -0.116308  1.000000
# highway-mpg       -0.040282           0.267929 -0.059326  0.972024
# price              0.083296           0.071176 -0.101519 -0.687186
# city-L/100km       0.041470          -0.298898  0.116510 -0.949692
# fuel-type-diesel   0.240013           0.985228 -0.476377  0.264947
# fuel-type-gas     -0.240013          -0.985228  0.476377 -0.264947
# aspiration-std    -0.215759          -0.307074  0.190696  0.191068
# aspiration-turbo   0.215759           0.307074 -0.190696 -0.191068
#
#                    highway-mpg     price  city-L/100km  fuel-type-diesel  \
# symboling             0.041248 -0.083327      0.062423         -0.195381
# normalized-losses    -0.182011  0.133999      0.238712         -0.101574
# wheel-base           -0.552211  0.589147      0.484047          0.306706
# length               -0.700186  0.691044      0.659174          0.210616
# width                -0.684700  0.752795      0.677111          0.243448
# height               -0.111568  0.137284      0.008923          0.281198
# curb-weight          -0.795515  0.834420      0.785868          0.221082
# engine-size          -0.679877  0.872337      0.745337          0.070925
# bore                 -0.590753  0.543431      0.554069          0.055371
# stroke               -0.040282  0.083296      0.041470          0.240013
# compression-ratio     0.267929  0.071176     -0.298898          0.985228
# peak-rpm             -0.059326 -0.101519      0.116510         -0.476377
# city-mpg              0.972024 -0.687186     -0.949692          0.264947
# highway-mpg           1.000000 -0.705115     -0.929940          0.197989
# price                -0.705115  1.000000      0.790291          0.110417
# city-L/100km         -0.929940  0.790291      1.000000         -0.240676
# fuel-type-diesel      0.197989  0.110417     -0.240676          1.000000
# fuel-type-gas        -0.197989 -0.110417      0.240676         -1.000000
# aspiration-std        0.243429 -0.179762     -0.158912         -0.407787
# aspiration-turbo     -0.243429  0.179762      0.158912          0.407787
#
#                    fuel-type-gas  aspiration-std  aspiration-turbo
# symboling               0.195381        0.050995         -0.050995
# normalized-losses       0.101574        0.006915         -0.006915
# wheel-base             -0.306706       -0.254907          0.254907
# length                 -0.210616       -0.229294          0.229294
# width                  -0.243448       -0.304459          0.304459
# height                 -0.281198       -0.086531          0.086531
# curb-weight            -0.221082       -0.322097          0.322097
# engine-size            -0.070925       -0.110278          0.110278
# bore                   -0.055371       -0.229304          0.229304
# stroke                 -0.240013       -0.215759          0.215759
# compression-ratio      -0.985228       -0.307074          0.307074
# peak-rpm                0.476377        0.190696         -0.190696
# city-mpg               -0.264947        0.191068         -0.191068
# highway-mpg            -0.197989        0.243429         -0.243429
# price                  -0.110417       -0.179762          0.179762
# city-L/100km            0.240676       -0.158912          0.158912
# fuel-type-diesel       -1.000000       -0.407787          0.407787
# fuel-type-gas           1.000000        0.407787         -0.407787
# aspiration-std          0.407787        1.000000         -1.000000
# aspiration-turbo       -0.407787       -1.000000          1.000000

# %%
# corr for particular columns

df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio
# bore               1.000000 -0.051087           0.002021
# stroke            -0.051087  1.000000           0.186761
# compression-ratio  0.002021  0.186761           1.000000

# %% [markdown]
# # Continuos Numerical variable

# %% [markdown]
# # Reg plot

# %% [markdown]
# ### (i) Engine-size and price

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 53604.87108851828)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872337
# price           0.872337  1.000000

# %% [markdown]
# ### Conclusion :
#     * When engine size increases, price also increases. which shows positive linear relationship.
#     * We can see that correlation between the engine size and price is 87% .
#     * where the engine size is good predictor variable for price.

# %% [markdown]
# ### (ii) Highway-mpg and price

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.705115
# price          -0.705115  1.000000

# %% [markdown]
# ### Conclusion:
#
#         * When the highway-mpg increases the price decreases.which is a Negative/Inverse linear relationship.
#         * Where the corr between the highway-mpg and price is -70%

# %% [markdown]
# ### (iii) peak-rpm and price

# %%
sns.regplot(x='peak-rpm',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101519
# price    -0.101519  1.000000

# %% [markdown]
# # Conclusion :
#
#     * Where the fitted line is close to horizontal.
#     * Also the points are very much scattered from the line.
#     * Therefore it is weak linear relationship and peak-rpm is not a good predictor for price.

# %% [markdown]
# ### (iv) stroke and price

# %%
sns.regplot(x='stroke',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
df[['stroke','price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.083296
# price   0.083296  1.000000

# %% [markdown]
# ### Conclusion :
#
#     * Where the fitted line is close to horizontal.
#     * Also the points are very much scattered from the line.
#     * Therefore it is weak linear relationship and stroke is not a good predictor for price.

# %% [markdown]
# # Categorical Variable

# %%
# Categorical variables -> count plot, bar plot, pie chart.
# if we have one numerical and one categorical then box plot also aplicable.

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='engine-location',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='engine-location', ylabel='price'>

# %% [markdown]
# ### Conclusion :
#
#     * where the price between the engine location is differs.
#     * where the engine location also a good predictor for price.

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# # Conclusion :
#
#     * Where the price between the different drive wheels differes.
#     * As the drive-wheels could potentially be a predictor of price.

# %% [markdown]
# # Descriptive Statistical Analysis :

# %%
# Automatically computes basic statistics for continuos variables.
# NaN values are automatically skipped.

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  200.000000         200.000000  200.000000  200.000000  200.000000
# mean     0.830000         122.000000   98.848000    0.494448    0.478462
# std      1.248557          32.076542    6.038261    0.184286    0.179735
# min     -2.000000          65.000000   86.600000    0.000000    0.000000
# 25%      0.000000         100.250000   94.500000    0.381716    0.331197
# 50%      1.000000         122.000000   97.000000    0.479104    0.444444
# 75%      2.000000         138.250000  102.400000    0.632836    0.544872
# max      3.000000         256.000000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  200.000000   200.000000   200.000000  200.000000  200.000000
# mean     0.499292  2555.705000   126.860000    3.330000    3.259847
# std      0.202371   518.594552    41.650501    0.268562    0.314177
# min      0.000000  1488.000000    61.000000    2.540000    2.070000
# 25%      0.350000  2163.000000    97.750000    3.150000    3.117500
# 50%      0.525000  2414.000000   119.500000    3.310000    3.290000
# 75%      0.643750  2928.250000   142.000000    3.582500    3.410000
# max      1.000000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio     peak-rpm    city-mpg  highway-mpg         price  \
# count         200.000000   200.000000  200.000000   200.000000    200.000000
# mean           10.170100  5118.181818   25.200000    30.705000  13205.690000
# std             4.014163   479.240110    6.432487     6.827227   7966.982558
# min             7.000000  4150.000000   13.000000    16.000000   5118.000000
# 25%             8.575000  4800.000000   19.000000    25.000000   7775.000000
# 50%             9.000000  5159.090909   24.000000    30.000000  10270.000000
# 75%             9.400000  5500.000000   30.000000    34.000000  16500.750000
# max            23.000000  6600.000000   49.000000    54.000000  45400.000000
#
#        city-L/100km  fuel-type-diesel  fuel-type-gas  aspiration-std  \
# count    200.000000        200.000000     200.000000      200.000000
# mean       9.937914          0.100000       0.900000        0.820000
# std        2.539415          0.300753       0.300753        0.385152
# min        4.795918          0.000000       0.000000        0.000000
# 25%        7.833333          0.000000       1.000000        1.000000
# 50%        9.791667          0.000000       1.000000        1.000000
# 75%       12.368421          0.000000       1.000000        1.000000
# max       18.076923          1.000000       1.000000        1.000000
#
#        aspiration-turbo
# count        200.000000
# mean           0.180000
# std            0.385152
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %% [markdown]
# # value_Counts :

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    126
# rwd     74
# Name: drive-wheels, dtype: int64

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           126
# rwd            74

# %% [markdown]
# # Correlation and Causation :

# %% [markdown]
#     * if the pvalue is <0.001 there is strong evidence that correlation is significant.
#     * if pvalue is <0.05 there is moderate evidence that correlation is significant.
#     * if pvalue is <0.1 there is weak evidence
#     * if pvalue is >0.1 there is no evidence.

# %%
from scipy import stats

# %%
# Wheel-Base vs Price

pearson_coef, p_value = stats.pearsonr(df['wheel-base'],df['price'])
print("The Pearson Correlation is",pearson_coef," with a p-value of p=",p_value)
# Out:
# The Pearson Correlation is 0.5891470005448702  with a p-value of p= 4.4570195020504053e-20

# %% [markdown]
# ### Conclusion :
#
#     * Since p-value is <0.001.
#     * Therefore the corr between wheel base and price is statistically significant.
#     * although the linear relationship isnt extremely strong.

# %%
# horsepower vs price

df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8097357390985241  with a P-value of P =  1.0089009233334041e-47

# %% [markdown]
# ### Conclusion :
#
#     * since p-value is <0.001.
#     * statistically significant.
#     * linear relationship quite strong.

# %%
# Engine-Size vs. Price

pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723367498521142  with a P-value of P = 1.8977171466563487e-63

# %% [markdown]
# ### Conclusion :
#
#     * since p-value is <0.001.
#     * statistically significant.
#     * linear relationship quite strong close to 1.

# %%
# Bore vs. Price

pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.5434310033088076  with a P-value of P =   9.20974963085112e-17

# %% [markdown]
# ### Conclusion :
#
#     * since p-value is <0.001.
#     * statistically significant.
#     * Although linear relationship not strong.

# %%
# City-mpg vs. Price

pearson_coef, p_value = stats.pearsonr(df['city-mpg'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6871861020862686  with a P-value of P =  2.729256568479228e-29

# %% [markdown]
# ### Conclusion :
#
#     * since p-value is <0.001.
#     * statistically significant.
#     * Although linear relationship is negative and modertley strong.

# %%
# Highway-mpg vs. Price

pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.7051147088046403  with a P-value of P =  2.1973260531584904e-31

# %% [markdown]
# ### Conclusion :
#
#     * since p-value is <0.001.
#     * statistically significant.
#     * Although linear relationship is negative and modertley strong.

# %% [markdown]
# # Conclusion : Important Variables

# %% [markdown]
# We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price.
#
# Continuous numerical variables:
#
#     Length
#     Width
#     Curb-weight
#     Engine-size
#     Horsepower
#     City-mpg
#     Highway-mpg
#     Wheel-base
#     Bore
# Categorical variables:
#
#     Drive-wheels
# As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.
